# %%
import torch

# %%
z1 = torch.load('/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_qwen_mmsb_features_pos_answers_14_multi_all_-1_test.pth')
z2 = torch.load('/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_qwen_mmsb_features_neg_answers_14_multi_all_-1_test.pth')
z3 = torch.load('/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_qwen_mmsb_features_context_14_multi_all_-1_test.pth')

# %%
z4 = torch.load('/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_qwen_mmsb_features_pos_answers_14_multi_all_-1_v2.pth')
z5 = torch.load('/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_qwen_mmsb_features_neg_answers_14_multi_all_-1_v2.pth')
z6 = torch.load('/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_qwen_mmsb_features_context_14_multi_all_-1.pth')

# %%
z4['hidden_states'][0].keys()
# Out:
# dict_keys(['model.layers.14'])

# %%
z3['hidden_states'][0].keys()
# Out:
# dict_keys(['model.layers.14'])

# %%
z3['hidden_states'][15]['model.layers.14']
# Out:
# {'inputs': {'last_raw_input': tensor([[-0.2156, -0.0585,  0.3140,  ..., -0.2744, -0.1875, -0.2634]],
#          dtype=torch.float16)},
#  'outputs': {'average': tensor([[nan, nan, nan,  ..., nan, nan, nan]], dtype=torch.float16),
#   'last_input': tensor([[-0.2156, -0.0585,  0.3140,  ..., -0.2744, -0.1875, -0.2634]],
#          dtype=torch.float16)}}

# %%
z6['hidden_states'][1500]['model.layers.14']
# Out:
# {'inputs': {'last_raw_input': tensor([[-0.2156, -0.0585,  0.3140,  ..., -0.2744, -0.1875, -0.2634]],
#          dtype=torch.float16)},
#  'outputs': {'average': tensor([[nan, nan, nan,  ..., nan, nan, nan]], dtype=torch.float16),
#   'last_input': tensor([[-0.2156, -0.0585,  0.3140,  ..., -0.2744, -0.1875, -0.2634]],
#          dtype=torch.float16)}}

# %%
k = 16
print(z1['hidden_states'][k]['model.layers.14'])
print(z2['hidden_states'][k]['model.layers.14'])
print(z4['hidden_states'][k*100]['model.layers.14'])
print(z5['hidden_states'][k*100]['model.layers.14'])
# Out:
# {'inputs': {'last_raw_input': tensor([[-0.3491,  0.4810, -0.4561,  ..., -0.5049,  0.3477, -1.2803]],
#        dtype=torch.float16)}, 'outputs': {'average': tensor([[-0.1921,  0.1757, -0.4700,  ..., -0.6919,  0.0685, -1.0293]],
#        dtype=torch.float16), 'last_input': tensor([[-0.2437, -0.0846, -0.6709,  ..., -0.7651,  0.3750, -0.8379]],
#        dtype=torch.float16)}}
# {'inputs': {'last_raw_input': tensor([[-0.1787,  0.1985, -0.3438,  ..., -0.6440,  0.6792, -0.3638]],
#        dtype=torch.float16)}, 'outputs': {'average': tensor([[ 0.1389,  0.5713, -0.0879,  ..., -0.8706, -0.1575, -0.4480]],
#        dtype=torch.float16), 'last_input': tensor([[-0.1787,  0.1985, -0.3438,  ..., -0.6440,  0.6792, -0.3638]],
#        dtype=torch.float16)}}
# {'inputs': {'last_raw_input': tensor([[-0.3491,  0.4810, -0.4561,  ..., -0.5049,  0.3477, -1.2803]],
#        dtype=torch.float16)}, 'outputs': {'average': tensor([[-0.1921,  0.1757, -0.4700,  ..., -0.6919,  0.0685, -1.0293]],
# ...
