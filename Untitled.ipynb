# %%
import torch

# %%
steer_vec = torch.load("/home/parekh/id_steering/test_code/llava_15_last_input_multi_mmsb_train_-1.pth")

# %%
z = steer_vec['steering_vector']

# %%
z[0][:, :5]
# Out:
# tensor([[ 0.0529,  0.0718,  0.0798,  0.2466, -0.1817]])

# %%
cxt_vec = torch.load("/home/parekh/id_steering/test_code/features/save_hidden_states_for_l2s_llava_mmsb_features_context_30_multi_all_-1.pth")

# %%
cxt_vec['hidden_states'][0]['language_model.model.layers.30']
# Out:
# {'inputs': {'last_raw_input': tensor([[ 1.6318, -0.0958,  0.2656,  ...,  0.3838,  3.7852,  0.1238]],
#          dtype=torch.float16)},
#  'outputs': {'average': tensor([[nan, nan, nan,  ..., nan, nan, nan]], dtype=torch.float16),
#   'last_input': tensor([[ 1.6318, -0.0958,  0.2656,  ...,  0.3838,  3.7852,  0.1238]],
#          dtype=torch.float16)}}
